# %% [markdown]
# <a href="https://colab.research.google.com/github/kyletsang0/midterm-project/blob/master/test_google_colad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/MidTerm/data/flights_test.csv')

# %%
df.head(50)
# Out:
#                 fl_date mkt_unique_carrier  ... flights distance
# 0   2020-01-01 00:00:00                 WN  ...       1      363
# 1   2020-01-01 00:00:00                 WN  ...       1      363
# 2   2020-01-01 00:00:00                 WN  ...       1      333
# 3   2020-01-01 00:00:00                 WN  ...       1      333
# 4   2020-01-01 00:00:00                 WN  ...       1      333
# 5   2020-01-01 00:00:00                 WN  ...       1      333
# 6   2020-01-01 00:00:00                 WN  ...       1      333
# 7   2020-01-01 00:00:00                 WN  ...       1      390
# 8   2020-01-01 00:00:00                 WN  ...       1      390
# 9   2020-01-01 00:00:00                 WN  ...       1      390
# 10  2020-01-01 00:00:00                 WN  ...       1      390
# 11  2020-01-01 00:00:00                 WN  ...       1      390
# 12  2020-01-01 00:00:00                 WN  ...       1      390
# ...
