# %% [markdown]
# # Data Wrangling

# %%
#Import libraries
import pandas as pd
pd.set_option('display.max_columns', None) # Display all the columns
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
sns.set(color_codes=True)

# %%
#Import data
path = '../../../data/'
df = pd.read_csv(str(path)+"flights_sample_10.csv",low_memory=False)

# %%
df_test = df[:10].copy()

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (1592444, 43)
# Unnamed: 0               int64
# fl_date                 object
# mkt_unique_carrier      object
# branded_code_share      object
# mkt_carrier             object
# mkt_carrier_fl_num       int64
# op_unique_carrier       object
# tail_num                object
# op_carrier_fl_num        int64
# origin_airport_id        int64
# origin                  object
# origin_city_name        object
# dest_airport_id          int64
# dest                    object
# dest_city_name          object
# crs_dep_time             int64
# dep_time               float64
# dep_delay              float64
# taxi_out               float64
# wheels_off             float64
# wheels_on              float64
# taxi_in                float64
# crs_arr_time             int64
# arr_time               float64
# arr_delay              float64
# cancelled                int64
# cancellation_code       object
# diverted                 int64
# dup                     object
# crs_elapsed_time       float64
# actual_elapsed_time    float64
# air_time               float64
# flights                  int64
# distance                 int64
# carrier_delay          float64
# weather_delay          float64
# nas_delay              float64
# security_delay         float64
# late_aircraft_delay    float64
# first_dep_time         float64
# total_add_gtime        float64
# longest_add_gtime      float64
# no_name                float64
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0     fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2018-05-29                 DL                 DL          DL
# 1           1  2018-05-29                 DL                 DL          DL
# 2           2  2018-05-29                 DL                 DL          DL
# 3           3  2018-05-29                 DL                 DL          DL
# 4           4  2018-05-29                 DL                 DL          DL
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 551                DL   N945DL                551
# 1                 565                DL   N918DH                565
# 2                 658                DL   N990DL                658
# 3                 678                DL   N365NB                678
# 4                 724                DL   N819DN                724
#
#    origin_airport_id origin    origin_city_name  dest_airport_id dest  \
# 0              10397    ATL         Atlanta, GA            11995  GSO
# 1              14100    PHL    Philadelphia, PA            11433  DTW
# 2              10397    ATL         Atlanta, GA            12448  JAN
# 3              11996    GSP           Greer, SC            11433  DTW
# 4              14869    SLC  Salt Lake City, UT            10849  BZN
#
#               dest_city_name  crs_dep_time  dep_time  dep_delay  taxi_out  \
# 0  Greensboro/High Point, NC          2331       2.0       31.0       9.0
# 1                Detroit, MI           600     554.0       -6.0      12.0
# 2      Jackson/Vicksburg, MS          1950    2016.0       26.0      33.0
# 3                Detroit, MI           600     555.0       -5.0      11.0
# 4                Bozeman, MT          2220    2301.0       41.0      10.0
#
#    wheels_off  wheels_on  taxi_in  crs_arr_time  arr_time  arr_delay  \
# 0        11.0       52.0     12.0            39     104.0       25.0
# 1       606.0      715.0      8.0           737     723.0      -14.0
# 2      2049.0     2046.0      7.0          2010    2053.0       43.0
# 3       606.0      722.0      7.0           750     729.0      -21.0
# 4      2311.0        4.0      5.0          2333       9.0       36.0
#
#    cancelled cancellation_code  diverted dup  crs_elapsed_time  \
# 0          0               NaN         0   N              68.0
# 1          0               NaN         0   N              97.0
# 2          0               NaN         0   N              80.0
# 3          0               NaN         0   N             110.0
# 4          0               NaN         0   N              73.0
#
#    actual_elapsed_time  air_time  flights  distance  carrier_delay  \
# 0                 62.0      41.0        1       306            0.0
# 1                 89.0      69.0        1       453            NaN
# 2                 97.0      57.0        1       341           18.0
# 3                 94.0      76.0        1       508            NaN
# 4                 68.0      53.0        1       347           36.0
#
#    weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# 0            0.0        0.0             0.0                 25.0
# 1            NaN        NaN             NaN                  NaN
# 2            0.0       17.0             0.0                  8.0
# 3            NaN        NaN             NaN                  NaN
# 4            0.0        0.0             0.0                  0.0
#
#    first_dep_time  total_add_gtime  longest_add_gtime  no_name
# 0             NaN              NaN                NaN      NaN
# 1             NaN              NaN                NaN      NaN
# 2             NaN              NaN                NaN      NaN
# 3             NaN              NaN                NaN      NaN
# 4             NaN              NaN                NaN      NaN

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                        Total   Percent
# no_name              1592444  1.000000
# total_add_gtime      1581485  0.993118
# first_dep_time       1581484  0.993117
# longest_add_gtime    1581484  0.993117
# cancellation_code    1565457  0.983053
# late_aircraft_delay  1291631  0.811100
# security_delay       1291631  0.811100
# nas_delay            1291631  0.811100
# weather_delay        1291631  0.811100
# carrier_delay        1291631  0.811100
# air_time               31627  0.019861
# arr_delay              31241  0.019618
# actual_elapsed_time    30990  0.019461
# taxi_in                28187  0.017700
# wheels_on              28185  0.017699
# arr_time               27544  0.017297
# taxi_out               27433  0.017227
# wheels_off             27431  0.017226
# dep_delay              26581  0.016692
# dep_time               26029  0.016345
# tail_num                5008  0.003145
# crs_elapsed_time           6  0.000004
# op_carrier_fl_num          0  0.000000
# op_unique_carrier          0  0.000000
# mkt_carrier_fl_num         0  0.000000
# dup                        0  0.000000
# origin                     0  0.000000
# mkt_carrier                0  0.000000
# branded_code_share         0  0.000000
# mkt_unique_carrier         0  0.000000
# fl_date                    0  0.000000
# origin_airport_id          0  0.000000
# dest_city_name             0  0.000000
# origin_city_name           0  0.000000
# dest_airport_id            0  0.000000
# dest                       0  0.000000
# diverted                   0  0.000000
# crs_dep_time               0  0.000000
# distance                   0  0.000000
# crs_arr_time               0  0.000000
# flights                    0  0.000000
# cancelled                  0  0.000000
# Unnamed: 0                 0  0.000000

# %%
df[df['arr_delay'].isnull()]
# Out:
#          Unnamed: 0    fl_date mkt_unique_carrier  mkt_carrier_fl_num  \
# 19               19 2018-05-29                 DL                 890
# 72               72 2018-05-29                 DL                1360
# 99               99 2018-05-29                 DL                1596
# 529             529 2018-05-29                 WN                 702
# 567             567 2018-05-29                 WN                1960
# ...             ...        ...                ...                 ...
# 1591544     1591544 2018-05-28                 WN                1903
# 1591562     1591562 2018-05-28                 WN                 823
# 1591685     1591685 2018-05-28                 DL                  43
# 1591869     1591869 2018-05-28                 DL                2169
# 1592170     1592170 2018-05-29                 DL                4195
#
#         tail_num origin dest  crs_dep_time  dep_time  dep_delay  taxi_out  \
# 19        N910AT    BDL  MSP          1656    1947.0      171.0      16.0
# 72        N851DN    ATL  BHM          1235    1233.0       -2.0       9.0
# 99        N837DN    MSP  LGA          1958    2107.0       69.0      24.0
# 529       N283WN    LAX  OAK          2250       NaN        NaN       NaN
# 567       N554WN    MDW  MSP          1605    1924.0      199.0      10.0
# ...          ...    ...  ...           ...       ...        ...       ...
# 1591544   N726SW    SAT  DEN          1415    1632.0      137.0      10.0
# 1591562   N569WN    SLC  DEN          1525       NaN        NaN       NaN
# 1591685   N318NB    JFK  MSP          1600    1553.0       -7.0      22.0
# 1591869   N698DL    LAS  ATL           926     924.0       -2.0      12.0
# 1592170   N438SW    ATL  CHA          2003    2019.0       16.0      19.0
#
#          wheels_off  wheels_on  taxi_in  crs_arr_time  arr_time  arr_delay  \
# 19           2003.0       13.0      4.0          1855      17.0        NaN
# 72           1242.0     1714.0      4.0          1225    1718.0        NaN
# 99           2131.0      728.0      7.0          2344     735.0        NaN
# 529             NaN        NaN      NaN             5       NaN        NaN
# 567          1934.0        NaN      NaN          1730       NaN        NaN
# ...             ...        ...      ...           ...       ...        ...
# 1591544      1642.0     2011.0      5.0          1530    2016.0        NaN
# 1591562         NaN        NaN      NaN          1650       NaN        NaN
# 1591685      1615.0     2008.0      3.0          1820    2011.0        NaN
# 1591869       936.0     2115.0     20.0          1615    2135.0        NaN
# 1592170      2038.0     2314.0      4.0          2049    2318.0        NaN
#
#          cancelled cancellation_code  diverted dup  crs_elapsed_time  \
# 19               0               NaN         1   N             179.0
# 72               0               NaN         1   N              50.0
# 99               0               NaN         1   N             166.0
# 529              1                 A         0   N              75.0
# 567              0               NaN         1   N              85.0
# ...            ...               ...       ...  ..               ...
# 1591544          0               NaN         1   N             135.0
# 1591562          1                 B         0   N              85.0
# 1591685          0               NaN         1   N             200.0
# 1591869          0               NaN         1   N             229.0
# 1592170          0               NaN         1   N              46.0
#
#          actual_elapsed_time  air_time  flights  distance  carrier_delay  \
# 19                       NaN       NaN        1      1050            NaN
# 72                       NaN       NaN        1       134            NaN
# 99                       NaN       NaN        1      1020            NaN
# 529                      NaN       NaN        1       337            NaN
# 567                      NaN       NaN        1       349            NaN
# ...                      ...       ...      ...       ...            ...
# 1591544                  NaN       NaN        1       794            NaN
# 1591562                  NaN       NaN        1       391            NaN
# 1591685                  NaN       NaN        1      1029            NaN
# 1591869                  NaN       NaN        1      1747            NaN
# 1592170                  NaN       NaN        1       106            NaN
#
#          weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# 19                 NaN        NaN             NaN                  NaN
# 72                 NaN        NaN             NaN                  NaN
# 99                 NaN        NaN             NaN                  NaN
# 529                NaN        NaN             NaN                  NaN
# 567                NaN        NaN             NaN                  NaN
# ...                ...        ...             ...                  ...
# 1591544            NaN        NaN             NaN                  NaN
# 1591562            NaN        NaN             NaN                  NaN
# 1591685            NaN        NaN             NaN                  NaN
# 1591869            NaN        NaN             NaN                  NaN
# 1592170            NaN        NaN             NaN                  NaN
#
#          first_dep_time  total_add_gtime  longest_add_gtime origin_state  \
# 19                  NaN              NaN                NaN           CT
# 72                  NaN              NaN                NaN           GA
# 99                  NaN              NaN                NaN           MN
# 529                 NaN              NaN                NaN           CA
# 567                 NaN              NaN                NaN           IL
# ...                 ...              ...                ...          ...
# 1591544             NaN              NaN                NaN           TX
# 1591562             NaN              NaN                NaN           UT
# 1591685             NaN              NaN                NaN           NY
# 1591869             NaN              NaN                NaN           NV
# 1592170             NaN              NaN                NaN           GA
#
#         dest_state
# 19              MN
# 72              AL
# 99              NY
# 529             CA
# 567             MN
# ...            ...
# 1591544         CO
# 1591562         CO
# 1591685         MN
# 1591869         GA
# 1592170         TN
#
# [31241 rows x 36 columns]

# %% [markdown]
# # Add Origin and destination State columns

# %%
df['origin_state'] = df['origin_city_name'].str[-2:]
df['dest_state'] = df['dest_city_name'].str[-2:]

# %%
#df

# %%
# for s in df.origin_state.value_counts().index.sort_values():
#     print(s)

# %%
(len(df.dest_state.value_counts()))
# Out:
# 53

# %% [markdown]
# # Convert to date time

# %%
df['fl_date'] = pd.to_datetime(df['fl_date'], format='%Y-%m-%d')
#df['crs_dep_time'] = pd.to_datetime(df['crs_dep_time'], format='%H%M')

# %% [markdown]
# # Fill missing values

# %%
df["tail_num"] = df["tail_num"].fillna('NA')

# %% [markdown]
# # Drop useless columns

# %%
#df = df.drop(['no_name','branded_code_share','mkt_carrier','op_unique_carrier','op_carrier_fl_num','origin_airport_id','origin_city_name','dest_airport_id','dest_city_name'],axis=1)
df.head(10)
# Out:
#    Unnamed: 0    fl_date mkt_unique_carrier  mkt_carrier_fl_num tail_num  \
# 0           0 2018-05-29                 DL                 551   N945DL
# 1           1 2018-05-29                 DL                 565   N918DH
# 2           2 2018-05-29                 DL                 658   N990DL
# 3           3 2018-05-29                 DL                 678   N365NB
# 4           4 2018-05-29                 DL                 724   N819DN
# 5           5 2018-05-29                 DL                 740   N872DN
# 6           6 2018-05-29                 DL                 746   N891AT
# 7           7 2018-05-29                 DL                 753   N322NB
# 8           8 2018-05-29                 DL                 755   N948DL
# 9           9 2018-05-29                 DL                 762   N929AT
#
#   origin dest  crs_dep_time  dep_time  dep_delay  taxi_out  wheels_off  \
# 0    ATL  GSO          2331       2.0       31.0       9.0        11.0
# 1    PHL  DTW           600     554.0       -6.0      12.0       606.0
# 2    ATL  JAN          1950    2016.0       26.0      33.0      2049.0
# 3    GSP  DTW           600     555.0       -5.0      11.0       606.0
# 4    SLC  BZN          2220    2301.0       41.0      10.0      2311.0
# 5    SEA  SLC          1825    1820.0       -5.0      11.0      1831.0
# 6    LEX  ATL           710     708.0       -2.0      12.0       720.0
# 7    LAX  MCI          1740    1756.0       16.0      12.0      1808.0
# 8    ATL  VPS          2245    2241.0       -4.0      17.0      2258.0
# 9    ATL  MDW          1625    1654.0       29.0      36.0      1730.0
#
#    wheels_on  taxi_in  crs_arr_time  arr_time  arr_delay  cancelled  \
# 0       52.0     12.0            39     104.0       25.0          0
# 1      715.0      8.0           737     723.0      -14.0          0
# 2     2046.0      7.0          2010    2053.0       43.0          0
# 3      722.0      7.0           750     729.0      -21.0          0
# 4        4.0      5.0          2333       9.0       36.0          0
# 5     2102.0      5.0          2119    2107.0      -12.0          0
# 6      823.0      5.0           834     828.0       -6.0          0
# 7     2306.0      5.0          2304    2311.0        7.0          0
# 8     2242.0      4.0          2256    2246.0      -10.0          0
# 9     1750.0      3.0          1721    1753.0       32.0          0
#
#   cancellation_code  diverted dup  crs_elapsed_time  actual_elapsed_time  \
# 0               NaN         0   N              68.0                 62.0
# 1               NaN         0   N              97.0                 89.0
# 2               NaN         0   N              80.0                 97.0
# 3               NaN         0   N             110.0                 94.0
# 4               NaN         0   N              73.0                 68.0
# 5               NaN         0   N             114.0                107.0
# 6               NaN         0   N              84.0                 80.0
# 7               NaN         0   N             204.0                195.0
# 8               NaN         0   N              71.0                 65.0
# 9               NaN         0   N             116.0                119.0
#
#    air_time  flights  distance  carrier_delay  weather_delay  nas_delay  \
# 0      41.0        1       306            0.0            0.0        0.0
# 1      69.0        1       453            NaN            NaN        NaN
# 2      57.0        1       341           18.0            0.0       17.0
# 3      76.0        1       508            NaN            NaN        NaN
# 4      53.0        1       347           36.0            0.0        0.0
# 5      91.0        1       689            NaN            NaN        NaN
# 6      63.0        1       304            NaN            NaN        NaN
# 7     178.0        1      1363            NaN            NaN        NaN
# 8      44.0        1       250            NaN            NaN        NaN
# 9      80.0        1       591            6.0            0.0        3.0
#
#    security_delay  late_aircraft_delay  first_dep_time  total_add_gtime  \
# 0             0.0                 25.0             NaN              NaN
# 1             NaN                  NaN             NaN              NaN
# 2             0.0                  8.0             NaN              NaN
# 3             NaN                  NaN             NaN              NaN
# 4             0.0                  0.0             NaN              NaN
# 5             NaN                  NaN             NaN              NaN
# 6             NaN                  NaN             NaN              NaN
# 7             NaN                  NaN             NaN              NaN
# 8             NaN                  NaN             NaN              NaN
# 9             0.0                 23.0             NaN              NaN
#
#    longest_add_gtime origin_state dest_state
# 0                NaN           GA         NC
# 1                NaN           PA         MI
# 2                NaN           GA         MS
# 3                NaN           SC         MI
# 4                NaN           UT         MT
# 5                NaN           WA         UT
# 6                NaN           KY         GA
# 7                NaN           CA         MO
# 8                NaN           GA         FL
# 9                NaN           GA         IL

# %% [markdown]
# # Question 1
# - remove cancelled flights
# - remove nan from dep_delay
# - Histogram dep_delays and get mean
# - Think about outliers
#
# - remove cancelled flights
# - remove nan from arr_delay
# - Histogram arr_delays and get mean
# - Think about outliers

# %%
# Remove canceled flights and dep_delay null values
df1a = df[(df.cancelled == 0) & df.dep_delay.notnull()]

# %%
x = df1a.dep_delay # all the values
xwo = x[x.between(x.quantile(.10), x.quantile(.90))] # without outliers

# %%
plt.figure(figsize=(10,5))
sns.distplot(xwo, bins=20, rug=True).set_title('Arrival delays without 10th and 90th quantile');

# %%
print(f'Departure delay median : {xwo.median()}')
print(f'Departure delay mean : {xwo.mean()}')
# Out:
# Departure delay median : -2.0
# Departure delay mean : 0.7856154846253857

# %%
# Remove canceled flights and arr_delay with null values
df1b = df[(df.cancelled == 0) & df.arr_delay.notnull()]

# %%
x = df1b.arr_delay # all the values
xwo = x[x.between(x.quantile(.10), x.quantile(.90))] # without outliers

# %%
plt.figure(figsize=(10,5))
sns.distplot(xwo, bins=20, rug=True).set_title('Arrival delays without 10th and 90th quantile');

# %%
print(f'Arrival delay median : {xwo.median()}')
print(f'Arrival delay mean : {xwo.mean()}')
# Out:
# Arrival delay median : -6.0
# Arrival delay mean : -3.2448565713430817
